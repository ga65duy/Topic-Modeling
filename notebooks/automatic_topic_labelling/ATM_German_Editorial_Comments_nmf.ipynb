# %%
import sys
sys.path.append('../..')
import src.Automatic_Topic_Labeling.lable_topic as tl
import src.data.data_loader as dl
from src.features.vectorizer import Vectorizer
from src.models.topic_models import TopicModel
# Out:
# C:\Users\Maria\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English

# %%
language = "german"
type = "editorial"
texttype = "article_texts"

language = "german"
type = "editorial"
texttype = "comment_texts"
model = "nmf"


vec = Vectorizer.load('vectorizer/nmf_german_editorial_without_bigrams.pkl')
tm = TopicModel.load('topic_models/nmf/nmf_german_editorial_without_bigrams_comments_170.pkl')

docs = tl.load_doc(language, type, texttype,"wobigrams")

labels = tl.get_topic_lables([],docs,[],model,vec,tm,n_top_words = 15, n_cand_lables = 100,lable_min_df = 15, n_labels = 8)

print("\nTopical labels:")
print("-" * 20)
for i, labels in enumerate(labels):
    print(u"Topic {}: {}\n".format(
        i,
        ', '.join(map(lambda l: ' '.join(l), labels))
    ))
# Out:
# PMI[[6.89854679 6.49308168 6.20539961 ... 6.89854679 6.89854679 6.72669653]
#  [6.88106983 6.47560472 6.18792265 ... 6.88106983 6.88106983 6.70921957]
#  [6.00948548 5.60402037 6.00948548 ... 6.00948548 6.00948548 6.53078241]
#  ...
#  [6.54161363 6.13614852 6.54161363 ... 6.54161363 6.54161363 7.06291055]
#  [5.86435583 5.45889072 5.17120865 ... 5.86435583 5.86435583 5.69250557]
#  [5.56621869 5.16075358 4.87307151 ... 5.56621869 5.56621869 5.39436843]]
# Topic modeling using nmf
#                         0               1               2               3  \
# Topic 0             zitat          dioxin    lebensmittel       kontrolle
# Topic 1             zitat    lebensmittel           essen             jed
# Topic 2               bio         produkt   konventionell    lebensmittel
# Topic 3             zitat             bio         produkt   konventionell
# Topic 4             bauer        bekommen           klein         preisen
# Topic 5               ddt           zitat         einsatz          afrika
# Topic 6           artikel     antibiotika          danken       kommentar
# Topic 7               jed  landwirtschaft           natur           essen
# Topic 8             milch        molkerei           bauer         betrieb
# Topic 9             zitat          gemüse           gurke           gülle
# Topic 10         pestizid        gesünder          studie     antibiotika
# Topic 11        schreiben       september       schmecken        gesünder
# Topic 12         olivenöl           teuer        qualität            ölen
# Topic 13             tier           leben          halten          finden
# Topic 14          preisen          kaufen           teuer     verbraucher
# Topic 15             huhn          balkon            hahn           eiern
# Topic 16         olivenöl       schmecken           liter       verwenden
# Topic 17          fleisch           essen             jed             all
# Topic 18            apfel            obst       schmecken      hauptsache
# Topic 19            leute           sehen            frei        molkerei
# Topic 20             ttip             usa             all          studie
# Topic 21      deutschland      österreich          billig     vergleichen
# Topic 22            gülle           zitat         spanien            feld
# Topic 23        schreiben          januar           essen         einfach
# Topic 24            gibts           <url>          finden         produkt
# Topic 25        schreiben            juli           essen          gesund
# Topic 26         pestizid   konventionell         artikel         produkt
# Topic 27     lebensmittel         problem          gemüse             zum
# Topic 28            essen         veganer         fleisch           vegan
# Topic 29              all             jed         einfach       schmecken
# ...                   ...             ...             ...             ...
# Topic 140      supermarkt         produkt            halt          direkt
# Topic 141            tier         emotion       lebewesen         schwein
# Topic 142          kaufen       biobauern            ware      österreich
# Topic 143         metzger            tier        tierwohl         siegeln
# Topic 144        pestizid         problem  landwirtschaft         schaden
# Topic 145          kosten  landwirtschaft      gentechnik           <url>
# Topic 146     antibiotika           natur       einsetzen  landwirtschaft
# Topic 147       konsument            coop         produkt          kaufen
# Topic 148           leben           essen          lassen           sehen
# Topic 149         siegeln           welch        öko-test      ökologisch
# Topic 150          kaufen            geld         handeln          konsum
# Topic 151       schreiben          januar          nitrat      subvention
# Topic 152          kaufen         italien      österreich    lebensmittel
# Topic 153            ttip       vertragen             usa           hören
# Topic 167  landwirtschaft         problem              wasser             all
# Topic 168        bekommen      subvention         produzieren      österreich
# Topic 169          ahnung           hofer             einfach      österreich
#
#                            8               9
# Topic 0                eiern             all
# Topic 1                  all             bio
# Topic 2                sehen           bauer
# Topic 3                frage           anbau
# Topic 4         lebensmittel       verkaufen
# Topic 5              problem  landwirtschaft
# Topic 6           gefährlich           autor
# Topic 7                leben         pflanze
# Topic 8              preisen            frei
# Topic 9          antibiotika         spargel
# Topic 10             artikel        forscher
# Topic 11              studie   konventionell
# Topic 12               <url>             öle
# Topic 13               genau           sehen
# Topic 14          discounter          kosten
# Topic 15                 pro           legen
# Topic 16        kürbiskernöl            test
# Topic 17             schwein             pro
# Topic 18               welch             öko
# Topic 19                 all            geld
# Topic 20       arbeitsplätze         bringen
# Topic 21              kosten         produkt
# Topic 22               bauer      ausbringen
# Topic 23               welch             und
# Topic 24               sehen        bekommen
# Topic 25      landwirtschaft             jed
# Topic 26          ökologisch            test
# Topic 27              liegen            obst
# Topic 28                 all         veganen
# Topic 29         vergleichen          lassen
# ...                      ...             ...
# Topic 140                jed         angebot
# Topic 141              sehen      artgerecht
# Topic 142           qualität          kennen
# Topic 143             kaufen     verbraucher
# Topic 144  biolandwirtschaft     tierhaltung
# Topic 145                all            huhn
# Topic 146                zum        beispiel
# Topic 147              kenia       verkaufen
# Topic 148             denken       verstehen
# Topic 149              essen          zeigen
# Topic 150              leute            euro
# Topic 151                the          liegen
# Topic 152              teuer         glauben
# Topic 153              markt        kündigen
# Topic 154              welch           leben
# Topic 155            schaden      wirtschaft
# Topic 156     landwirtschaft             all
# Topic 157                zum        beispiel
# Topic 158         eigentlich            euro
# Topic 159         esoterisch       schreiben
# Topic 160                all       betreiben
# Topic 161          bratwurst           essen
# Topic 162              leute         gulasch
# Topic 163           deutlich       geschmack
# Topic 164            betrieb          arbeit
# Topic 165                övp         einfach
# Topic 166           bekommen     förderungen
# Topic 167             nitrat     deutschland
# Topic 168     landwirtschaft         fördern
# Topic 169         supermarkt          fragen
#
# [170 rows x 10 columns]
# shape topic model
# (170, 15193)
# pmishape
# (15162, 100)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-3d84a7b7d107> in <module>()
#      14 docs = tl.load_doc(language, type, texttype,"wobigrams")
#      15
# ---> 16 labels = tl.get_topic_lables([],docs,[],model,vec,tm,n_top_words = 15, n_cand_lables = 100,lable_min_df = 15, n_labels = 8)
#      17
#      18 print("\nTopical labels:")
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\lable_topic.py in get_topic_lables(tagged_docs, docs, pos, model, vec, trained_tm, n_top_words, n_cand_lables, lable_min_df, n_labels)
#      86                                index2label=pmi_cal.index2label_,
#      87                                label_models=None,
# ---> 88                                k = n_labels)
#      89     return labels
#      90
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in top_k_labels(self, topic_models, pmi_w2l, index2label, label_models, k)
#     212         label_scores = self.combined_label_score(topic_models, pmi_w2l,
#     213                                                  self._discrimination,
# --> 214                                                  self._mu)
#     215
#     216         print("lable scores")
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in combined_label_score(self, topic_models, pmi_w2l, use_discrimination, mu)
#     147             score for each topic and label pair
#     148         """
# --> 149         rel_scores = self.label_relevance_score(topic_models, pmi_w2l)
#     150
#     151         if use_discrimination:
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in label_relevance_score(self, topic_models, pmi_w2l)
#      52
#      53
# ---> 54         assert topic_models.shape[1] == pmi_w2l.shape[0]
#      55         return np.asarray(np.asmatrix(topic_models) *
#      56                           np.asmatrix(pmi_w2l))
#
# AssertionError:
