# %%
import sys
sys.path.append('../..')
import src.Automatic_Topic_Labeling.lable_topic as tl
import src.data.data_loader as dl
from src.features.vectorizer import Vectorizer
from src.models.topic_models import TopicModel
# Out:
# C:\Users\Maria\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English

# %%
language = "german"
type = "forum"
texttype = "thread_texts"
model = "nmf"

vec = Vectorizer.load('vectorizer/nmf_german_forum_without_bigrams.pkl')
tm = TopicModel.load('topic_models/nmf/nmf_german_forum_without_bigrams170.pkl')
docs = dl.get_articles_by_sources(["spiegel","zeit"],kind = "wobigrams")

#docs = tl.load_doc(language, type, texttype,"wobigrams")

# %%
labels = tl.get_topic_lables([],docs,[],model,vec,tm,n_top_words = 15, n_cand_lables = 100,lable_min_df = 15, n_labels = 8)
print("\nTopical labels:")
print("-" * 20)
for i, labels in enumerate(labels):
    print(u"Topic {}: {}\n".format(
        i,
        ', '.join(map(lambda l: ' '.join(l), labels))
    ))
# Out:
# PMI[[3.16449216 4.34314715 1.70408982 ... 4.34314715 3.78353136 4.1200036 ]
#  [3.70554924 4.19105705 2.2451469  ... 4.19105705 4.32458845 4.66106068]
#  [4.25931994 4.74482776 2.79891761 ... 4.74482776 4.87835915 5.21483139]
#  ...
#  [3.82845778 5.00711278 3.06120263 ... 5.00711278 3.75434981 4.78396923]
#  [5.18966255 5.67517037 3.72926022 ... 5.67517037 5.80870176 5.45202682]
#  [6.3119742  7.4906292  4.85157187 ... 7.4906292  6.23786623 7.26748565]]
# Topic modeling using nmf
#                         0                         1                    2  \
# Topic 0             kaufe                       bio           supermarkt
# Topic 1               bio                   produkt           bio-siegel
# Topic 2              tier                   haltung           schlachten
# Topic 3             <url>                    finden            bio-markt
# Topic 4    landwirtschaft                ökologisch          biologische
# Topic 5           veganer                  ernähren                leben
# Topic 6             eiern                      huhn              bioeier
# Topic 7             milch                       kuh            bio-milch
# Topic 8             bauer                     hafer            verkaufen
# Topic 9              obst                    gemüse               normal
# Topic 10            woche                     monat                 euro
# Topic 11        kartoffel                    keimen                sorte
# Topic 12     lebensmittel                     welch              nahrung
# Topic 13           kaufen                    zusatz              sichern
# Topic 14             rewe                     penny                 aldi
# Topic 15           zucker                rohrzucker                braun
# Topic 16          preisen                      euro                 kilo
# Topic 17            vegan                    vegane            margarine
# Topic 18          saatgut                     biene              züchten
# Topic 19      deutschland                    google               kaputt
# Topic 20         gesünder                    studie        inhaltsstoffe
# Topic 21            apfel                     belag            schimmeln
# Topic 22              hof  landwirtschaftspraktikum            praktikum
# Topic 23          plastik                 einpacken         unbedenklich
# Topic 24         regional                 regionale               region
# Topic 25          referat                  eingehen                thema
# Topic 26            thema                   projekt            community
# Topic 27          politik                     thema                japan
# Topic 28          garnele                     aroma         bio-garnelen
# Topic 29            gurke                    schale              schalen
# ...                   ...                       ...                  ...
# Topic 140          nudeln                    lecker                snack
# Topic 141       vorschlag                    themen                thema
# Topic 142          papier               bezeichnung           herstellen
# Topic 143            käse                  erlauben                  lab
# Topic 144      giftstoffe                infizieren            benutzung
# Topic 145      nährstoffe                       hau           sonderlich
# Topic 146          ballen                    hektar                wiese
# Topic 147        umfragen                teilnehmen                 link
# Topic 148        dortmund                  hofladen  nordrhein-westfalen
# Topic 149            ruhe                   konzept                  tod
# Topic 150   zitronensäure                     china            drumherum
# Topic 151     plastiktüte      gesundheitsschädlich               dinger
# Topic 152          nervig                 eindämmen               beißen
# Topic 153          fläche                    nummer           beantragen
# Topic 154            norm                festgelegt               normen
# Topic 155   konventionell               unterschied                 bier
# Topic 156           sirup                      saft             intensiv
# Topic 157          möbeln                verblüffen           biologisch
# Topic 158           erden                  sinnvoll          bevölkerung
# Topic 159          schatz                 landkreis           berechnung
# Topic 160          wasser                 biowasser       leitungswasser
# Topic 161      tierfutter         demeter-produkten                 plan
# Topic 162        erdkunde                fußabdruck              youtube
# Topic 163     anforderung                    hasten           verordnung
# Topic 164           lunge                   raucher                teile
# Topic 165          weizen                  getreide               gerste
# Topic 166       naturkost         bio-lebensmitteln           biologisch
# Topic 167           gerät                    missen          kühlschrank
# Topic 168          lernen                    fehler            förderung
# Topic 169         gewusst                  spiegeln            tätigkeit
#
#                            3               4               5  \
# Topic 0               kaufen          gemüse       schmecken
# Topic 1              meinung      wirtschaft          normal
# Topic 2                töten         schwein          halten
# Topic 3           demeterhof          suchen  empfehlenswert
# Topic 4        konventionell       erzeugnis           thema
# Topic 5                essen            sekt           vegan
# Topic 6               dotter    bodenhaltung        bio-eier
# Topic 7             biomilch  homogenisieren           bauer
# Topic 8               direkt         ausland          fragen
# Topic 9                  usa          saison         waschen
# Topic 10               essen            geld          sparen
# Topic 11      bio-kartoffeln           boden      kartoffeln
# Topic 12        verschimmeln          abfall       schmecken
# Topic 13          biologisch         bioware          region
# Topic 14                lidl           edeka        kaufland
# Topic 15          zuckerrohr            weiß      biologisch
# Topic 16              kosten           teuer            cent
# Topic 17             veganen           erdöl         muffins
# Topic 18      grundsaetzlich         pflanze         aussäen
# Topic 19                kauf     importieren       statistik
# Topic 20             vitamin       enthalten         normale
# Topic 21          schokolade            fett         waschen
# Topic 22       waldorfschule         england       bauernhof
# Topic 23                rewe            push  unterschreiben
# Topic 24             ägypten    regionalität   fragestellung
# Topic 25          gliederung        könntest           genau
# Topic 26           erstellen          arbeit  nachhaltigkeit
# Topic 27              weiter             und      radioaktiv
# Topic 28                meer     medikamente            fuer
# Topic 29           bio-gurke       unehrlich    plastikfolie
# ...                      ...             ...             ...
# Topic 140               fand            lieb           sosse
# Topic 141           gefallen            note            wahl
# Topic 142           vielfach     schwachsinn      gebrauchen
# Topic 143         bio-siegel           bitte       nirgendwo
# Topic 144         vermischen           dosen         nahrung
# Topic 145  abwechslungsreich       studentin      speiseplan
# Topic 146                heu             pro             ddr
# Topic 147          teilnahme         beenden            edit
# Topic 148        bauernladen            bier             tee
# Topic 149          furchtbar          letzte         sichern
# Topic 150            analyse          import         konzern
# Topic 151               brei           essen        abbaubar
# Topic 152         verpackung          fällen            rein
# Topic 153           anmelden   bauernverband            kalb
# Topic 154             werten           regel             bzw
# Topic 155                vs.       schmecken       geschmack
# Topic 156             zucker          frucht           süßen
# Topic 157             halten         stellen     herbekommen
# Topic 165             keimfähig          nutzpflanzen     versandhandel
# Topic 166             bio-anbau              rechnung        freundlich
# Topic 167                 siehe                 salat            vorrat
# Topic 168               gebären                 insel        tierschutz
# Topic 169             beruflich              einreden        bio-gemüse
#
#                               9
# Topic 0                   bauer
# Topic 1                   drauf
# Topic 2             artgerechte
# Topic 3              umstellung
# Topic 4                 merkmal
# Topic 5                    tier
# Topic 6                     all
# Topic 7              heutzutage
# Topic 8                 nahrung
# Topic 9                 bioobst
# Topic 10                 person
# Topic 11                   mist
# Topic 12                 finden
# Topic 13                 umwelt
# Topic 14                   weiß
# Topic 15             zuckerrübe
# Topic 16                 billig
# Topic 17             pflanzlich
# Topic 18           entsprechend
# Topic 19                 leider
# Topic 20                 normal
# Topic 21        beeinträchtigen
# Topic 22             frankreich
# Topic 23              verlangen
# Topic 24      bio-lebensmitteln
# Topic 25              demnächst
# Topic 26               biologie
# Topic 27            befruchtung
# Topic 28   konservierungsmittel
# Topic 29                wässern
# ...                         ...
# Topic 140                  kenn
# Topic 141             kartoffel
# Topic 142             sogenannt
# Topic 143           theoretisch
# Topic 144          interessante
# Topic 145                 total
# Topic 146               streuen
# Topic 147            fragebogen
# Topic 148                 honig
# Topic 149          antibiotikum
# Topic 150              rapunzel
# Topic 151                  chip
# Topic 152               warnung
# Topic 153               gründen
# Topic 154             wikipedia
# Topic 155            magerquark
# Topic 156                 sowas
# Topic 157                dachte
# Topic 158                wurzel
# Topic 159        landwirtschaft
# Topic 160             schütteln
# Topic 161             bio-milch
# Topic 162                lehrer
# Topic 163           bio-fleisch
# Topic 164             garnichts
# Topic 165               aussäen
# Topic 166      bio-lebensmittel
# Topic 167           haltbarkeit
# Topic 168            wirtschaft
# Topic 169                 kaufe
#
# [170 rows x 10 columns]
# shape topic model
# (170, 7214)
# pmishape
# (7195, 100)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-1dbf77138943> in <module>()
# ----> 1 labels = tl.get_topic_lables([],docs,[],model,vec,tm,n_top_words = 15, n_cand_lables = 100,lable_min_df = 15, n_labels = 8)
#       2 print("\nTopical labels:")
#       3 print("-" * 20)
#       4 for i, labels in enumerate(labels):
#       5     print(u"Topic {}: {}\n".format(
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\lable_topic.py in get_topic_lables(tagged_docs, docs, pos, model, vec, trained_tm, n_top_words, n_cand_lables, lable_min_df, n_labels)
#      86                                index2label=pmi_cal.index2label_,
#      87                                label_models=None,
# ---> 88                                k = n_labels)
#      89     return labels
#      90
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in top_k_labels(self, topic_models, pmi_w2l, index2label, label_models, k)
#     212         label_scores = self.combined_label_score(topic_models, pmi_w2l,
#     213                                                  self._discrimination,
# --> 214                                                  self._mu)
#     215
#     216         print("lable scores")
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in combined_label_score(self, topic_models, pmi_w2l, use_discrimination, mu)
#     147             score for each topic and label pair
#     148         """
# --> 149         rel_scores = self.label_relevance_score(topic_models, pmi_w2l)
#     150
#     151         if use_discrimination:
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in label_relevance_score(self, topic_models, pmi_w2l)
#      52
#      53
# ---> 54         assert topic_models.shape[1] == pmi_w2l.shape[0]
#      55         return np.asarray(np.asmatrix(topic_models) *
#      56                           np.asmatrix(pmi_w2l))
#
# AssertionError:
