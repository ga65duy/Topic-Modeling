# %%
import sys
sys.path.append('../..')
import src.Automatic_Topic_Labeling.lable_topic as tl
import src.data.data_loader as dl
from src.features.vectorizer import Vectorizer
from src.models.topic_models import TopicModel
# Out:
# C:\Users\Maria\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English

# %%
language = "english"
typetx = "editorial"
texttype = "comment_texts"
model = "lda"


vec = Vectorizer.load('vectorizer/lda_english_editorial_without_bigrams_test.pkl')
tm = TopicModel.load('topic_models/lda/lda_english_editorial_without_bigrams_test130.pkl')
docs = dl.get_articles_by_sources(["spiegel","zeit"],kind = "wobigrams")

#docs = tl.load_doc(language, typetx, texttype)

labels = tl.get_topic_lables([],docs,[],model,vec,tm,n_top_words = 15, n_cand_lables = 100,lable_min_df = 15, n_labels = 8)


print("\nTopical labels:")
print("-" * 20)
for i, labels in enumerate(labels):
        print(u"Topic {}: {}\n".format(
            i,
            ', '.join(map(lambda l: ' '.join(l), labels))
        ))
# Out:
# WARNING:root:After label filtering, there is nothing left.
# []
# PMI[]
# Topic modeling using lda
#                      0           1                2             3  \
# Topic 0           fall     surpass             grow       revenue
# Topic 1         county        farm             land          team
# Topic 2        science    chemical             good          like
# Topic 3          <url>  technology  target="_blank"          year
# Topic 4        organic        crop          farming  conventional
# Topic 5         frozen   vegetable            fresh         fruit
# Topic 6        vitamin        food             diet          good
# Topic 7           root   blueberry            plant           way
# Topic 8        service        food           expand           use
# Topic 9         philip      philly              phd      pheasant
# Topic 10     corporate       house              big         water
# Topic 11        philip      philly              phd      pheasant
# ...
