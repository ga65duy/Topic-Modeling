# %%
import sys
sys.path.append('../..')
import src.Automatic_Topic_Labeling.lable_topic as tl
import src.data.data_loader as dl
from src.features.vectorizer import Vectorizer
from src.models.topic_models import TopicModel
# Out:
# C:\Users\Maria\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English

# %%
language = "english"
typetx = "editorial"
texttype = "comment_texts"
model = "nmf"

vec = Vectorizer.load('vectorizer/nmf_english_editorial_without_bigrams.pkl')
tm = TopicModel.load('topic_models/nmf/nmf_english_editorial_without_bigrams_comments170.pkl')

docs = tl.load_doc(language, typetx, texttype,"wobigrams")

labels = tl.get_topic_lables([],docs,[],model,vec,tm,n_top_words = 15, n_cand_lables = 100,lable_min_df = 15, n_labels = 8)


print("\nTopical labels:")
print("-" * 20)
for i, labels in enumerate(labels):
        print(u"Topic {}: {}\n".format(
            i,
            ', '.join(map(lambda l: ' '.join(l), labels))
        ))
# Out:
# PMI[[8.40841124 8.02274876 8.06357075 ... 7.09848986 6.76428777 7.60403842]
#  [5.40587977 4.32707011 5.06103929 ... 3.40281121 3.7617563  5.29465414]
#  [6.47060244 6.08493996 6.12576195 ... 5.16068106 6.21277333 6.3593768 ]
#  ...
#  [4.49614877 4.11048629 4.15130828 ... 3.18622739 3.54517248 4.38492313]
#  [6.8813727  6.49571022 5.84338503 ... 4.87830413 5.93039641 6.77014706]
#  [7.0084737  5.92966404 5.97048603 ... 5.69855232 6.05749741 6.20410088]]
# Topic modeling using nmf
#                       0                1           2              3  \
# Topic 0            food              eat      people         health
# Topic 1          amazon            foods       price          bezos
# Topic 2         organic     conventional   pesticide           good
# Topic 3             gmo         monsanto        crop           gene
# Topic 4          farmer           market        farm           sell
# Topic 5          animal             meat       vegan          plant
# Topic 6             egg             cage     chicken            hen
# Topic 7           /><br              />i        food          />the
# Topic 8         grocery            store        good           shop
# Topic 9            milk              cow       dairy            raw
# Topic 10        chicken       antibiotic  administer        arsenic
# Topic 11           wine        winemaker  biodynamic          grape
# Topic 12            fat          calorie        diet         weight
# Topic 13           food  expiration_date       waste         unsafe
# Topic 14      pesticide            study         use       chemical
# Topic 15          foods            price       store     trader_joe
# Topic 16           crop          subsidy        corn      vegetable
# Topic 17            bee        beekeeper  pollinator           seed
# Topic 18           beef            grass        feed          grain
# Topic 19         frozen            fresh   vegetable          fruit
# Topic 20          cyber           monday        deal          <url>
# Topic 21          <url>           rodale  integrated     regulation
# Topic 22         soccer           county        land          lease
# Topic 23           aldi            store        chip          wally
# Topic 24           farm        calculate     product           acre
# Topic 25       biosolid            waste      sewage         sludge
# Topic 26            cat              pet         dog            vet
# Topic 27         potato             grow      sprout        buttery
# Topic 28    interesting             coke    position           sell
# Topic 29        vitamin            level       study        mineral
# ...                 ...              ...         ...            ...
# Topic 140       sorghum         villager      indian          guilt
# Topic 141         hurry            swamp    polluter      corporate
# Topic 142        worker     undocumented  commission            pay
# Topic 143          oats          oatmeal   breakfast           carb
# Topic 144       biofuel          climate     ethanol           crop
# Topic 145           cvs     prescription        drug       pharmacy
# Topic 146         false            wrist     company           make
# Topic 147        burger          protein       vegan            eat
# Topic 148        amazon         checkout       bezos           jeff
# Topic 149     preferred      demographic       lower           shop
# Topic 150          fwiw           mobile     segment        payment
# Topic 151        friday            black      member       dividend
# Topic 166             good           grow               apple    newspaper
# Topic 167       profitable  profitability               china      trigger
# Topic 168           kroger        shopper             product    inversely
# Topic 169          smother            bag                soil        plant
#
#                         8              9
# Topic 0           healthy           know
# Topic 1          customer            buy
# Topic 2               non        produce
# Topic 3              seed         modify
# Topic 4            people         tomato
# Topic 5             human         people
# Topic 6            coyote            lay
# Topic 7       freshdirect     government
# Topic 8          district        butcher
# Topic 9    pasteurization       industry
# Topic 10       salmonella           idea
# Topic 11            label    viticulture
# Topic 12          healthy           lose
# Topic 13         recovery           help
# Topic 14            human           pest
# Topic 15            giant      expensive
# Topic 16        subsidize        soybean
# Topic 17           flower           nest
# Topic 18          pasture            fed
# Topic 19           canned         veggie
# Topic 20            house           good
# Topic 21            small        johnson
# Topic 22             farm        leggett
# Topic 23      inexpensive           turn
# Topic 24          problem          large
# Topic 25          compost      hazardous
# Topic 26         equation      carnivore
# Topic 27             warm           good
# Topic 28          clearly        canning
# Topic 29          calcium            sun
# ...                   ...            ...
# Topic 140             aka          flour
# Topic 141     independent        typical
# Topic 142            fair            tax
# Topic 143        diabetes          blood
# Topic 144       petroleum      pollution
# Topic 145            high        company
# Topic 146       hopefully            hit
# Topic 147            good           free
# Topic 148    installation      guacamole
# Topic 149          people          right
# Topic 150           think         sprout
# Topic 151           store          place
# Topic 152             dow        article
# Topic 153            sell            add
# Topic 154           paint          green
# Topic 155         organic       customer
# Topic 156       vegetable            mom
# Topic 157            skin           body
# Topic 158            grow          <url>
# Topic 159         plateau        chagrin
# Topic 160           tower       turnover
# Topic 161            cook         people
# Topic 162      toothbrush      quarterly
# Topic 163          access  sanctimonious
# Topic 164       willfully         idiocy
# Topic 165         million     deregulate
# Topic 166            poor         bruise
# Topic 167          global           test
# Topic 168         walmart            big
# Topic 169        chemical        mixture
#
# [170 rows x 10 columns]
# shape topic model
# (170, 11714)
# pmishape
# (11659, 100)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-89e8ddd17ffc> in <module>()
#       9 docs = tl.load_doc(language, typetx, texttype,"wobigrams")
#      10
# ---> 11 labels = tl.get_topic_lables([],docs,[],model,vec,tm,n_top_words = 15, n_cand_lables = 100,lable_min_df = 15, n_labels = 8)
#      12
#      13
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\lable_topic.py in get_topic_lables(tagged_docs, docs, pos, model, vec, trained_tm, n_top_words, n_cand_lables, lable_min_df, n_labels)
#      86                                index2label=pmi_cal.index2label_,
#      87                                label_models=None,
# ---> 88                                k = n_labels)
#      89     return labels
#      90
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in top_k_labels(self, topic_models, pmi_w2l, index2label, label_models, k)
#     212         label_scores = self.combined_label_score(topic_models, pmi_w2l,
#     213                                                  self._discrimination,
# --> 214                                                  self._mu)
#     215
#     216         print("lable scores")
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in combined_label_score(self, topic_models, pmi_w2l, use_discrimination, mu)
#     147             score for each topic and label pair
#     148         """
# --> 149         rel_scores = self.label_relevance_score(topic_models, pmi_w2l)
#     150
#     151         if use_discrimination:
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in label_relevance_score(self, topic_models, pmi_w2l)
#      52
#      53
# ---> 54         assert topic_models.shape[1] == pmi_w2l.shape[0]
#      55         return np.asarray(np.asmatrix(topic_models) *
#      56                           np.asmatrix(pmi_w2l))
#
# AssertionError:
