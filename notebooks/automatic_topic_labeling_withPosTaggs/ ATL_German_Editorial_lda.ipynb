# %% [markdown]
# ## ATL for german editorial articles

# %%
import sys
sys.path.append('../..')
import src.Automatic_Topic_Labeling.lable_topic as tl
import src.Automatic_Topic_Labeling.helper_functions as hp
import src.data.data_loader as dl
from src.features.vectorizer import Vectorizer
from src.models.topic_models import TopicModel
# Out:
# C:\Users\Maria\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English

# %% [markdown]
# ### 1-Load tags and documents

# %%
data = dl.get_articles_by_type("german", "editorial",merge_tokens=False, kind='tagged')
article_texts = data["article_texts"]
article_pos = data["article_pos"]
pos=[("NN","NN"),('ADJD', 'NN')]

# %% [markdown]
# ### 2-Load Vectorizer and Topic model

# %%
vec = Vectorizer.load('tagged/vectorizer/lda_german_article_texts_pos.pkl')
tm = TopicModel.load('tagged/topic_models/lda/lda_german_article_texts_tagged_190.pkl')

# %% [markdown]
# ### 3-Generate Topic Lables with Pos-Tags

# %%
labels_pos = tl.get_topic_lables(article_pos,article_texts,pos,vec,tm,n_cand_lables = 100,lable_min_df = 5, n_labels = 5)
# Out:
# shape topic model
# (190, 5496)
# pmishape
# (5496, 100)

# %%
display(hp.print_label_df(tm,labels_pos))
# Out:
#                         0           1             2                     3  \
# Topic 0         probieren         pro  produktions-            produktion
# Topic 1         probieren         pro  produktions-            produktion
# Topic 2         probieren         pro  produktions-            produktion
# Topic 3            aigner     betrieb         sagen               skandal
# Topic 4         probieren         pro  produktions-            produktion
# Topic 5             nicht         die          auch                   als
# Topic 6         probieren         pro  produktions-            produktion
# Topic 7              sich       haben           die                  jahr
# Topic 8        umstellung        sich        lassen              beratung
# Topic 9              baby       ernst        london         problematisch
# Topic 10        probieren         pro  produktions-            produktion
# Topic 11        probieren         pro  produktions-            produktion
# ...

# %% [markdown]
# ### All generated lables per topic

# %%
print("\nTopical labels:")
print("-" * 20)
for i, labels in enumerate(labels_pos):
    print(u"Topic {}: {}\n".format(
        i,
        ', '.join(map(lambda l: ' '.join(l), labels))
    ))
# Out:
# Topical labels:
# --------------------
# Topic 0: ökoschule hausen, unternehmer betrugsverdachtsfälle, einzelhandelsmarken ringen, farbstoff erythrosin, billion dollar
#
# Topic 1: ökoschule hausen, unternehmer betrugsverdachtsfälle, einzelhandelsmarken ringen, farbstoff erythrosin, billion dollar
#
# Topic 2: ökoschule hausen, unternehmer betrugsverdachtsfälle, einzelhandelsmarken ringen, farbstoff erythrosin, billion dollar
#
# Topic 3: verbraucherschutz laves, foods oetker-gruppe, billionstel gramm, verbotene verwendung, hilfsorganisation oxfam
#
# Topic 4: ökoschule hausen, unternehmer betrugsverdachtsfälle, einzelhandelsmarken ringen, farbstoff erythrosin, billion dollar
#
# Topic 5: centralen marketinggesellschaft, foods oetker-gruppe, hilfsorganisation oxfam, bohne erbse, pflanzgut ag
#
# Topic 6: ökoschule hausen, unternehmer betrugsverdachtsfälle, einzelhandelsmarken ringen, farbstoff erythrosin, billion dollar
#
# ...

# %% [markdown]
# ## Labels without Pos-Tags

# %%
labels = tl.get_topic_lables([],article_texts,None,vec,tm,n_cand_lables = 100,lable_min_df = 5, n_labels = 5)
# Out:
# shape topic model
# (190, 5496)
# pmishape
# (5496, 100)

# %%
display(hp.print_label_df(tm,labels))
# Out:
#                         0           1             2                     3  \
# Topic 0         probieren         pro  produktions-            produktion
# Topic 1         probieren         pro  produktions-            produktion
# Topic 2         probieren         pro  produktions-            produktion
# Topic 3            aigner     betrieb         sagen               skandal
# Topic 4         probieren         pro  produktions-            produktion
# Topic 5             nicht         die          auch                   als
# Topic 6         probieren         pro  produktions-            produktion
# Topic 7              sich       haben           die                  jahr
# Topic 8        umstellung        sich        lassen              beratung
# Topic 9              baby       ernst        london         problematisch
# Topic 10        probieren         pro  produktions-            produktion
# Topic 11        probieren         pro  produktions-            produktion
# ...

# %% [markdown]
# ### All generated lables per topic

# %%
print("\nTopical labels:")
print("-" * 20)
for i, label in enumerate(labels):
    print(u"Topic {}: {}\n".format(
        i,
        ', '.join(map(lambda l: ' '.join(l), label))
    ))
# Out:
# Topical labels:
# --------------------
# Topic 0: demner merlicek, listeria monocytogenes, alma win, guignard kessler, justine rosinski
#
# Topic 1: demner merlicek, listeria monocytogenes, alma win, guignard kessler, justine rosinski
#
# Topic 2: demner merlicek, listeria monocytogenes, alma win, guignard kessler, justine rosinski
#
# Topic 3: großbäcker lactalis-babynahrung, hans-wilhelm windhorst, benno bruggink, infratest dimap, landauf landab
#
# Topic 4: demner merlicek, listeria monocytogenes, alma win, guignard kessler, justine rosinski
#
# Topic 5: jürn sanders, benno schirrmeister, landauf landab, hans-wilhelm windhorst, handelsforschung ifh
#
# Topic 6: demner merlicek, listeria monocytogenes, alma win, guignard kessler, justine rosinski
#
# Topic 7: benno schirrmeister, jürn sanders, hans-wilhelm windhorst, pinot noir, handelsforschung ifh
#
# Topic 8: landesprogramm bioregio, pinot noir, são paulo, jürn sanders, grande do
#
# ...

# %% [markdown]
# ## Labels with Bigrams

# %%
article_data_bi = dl.get_articles_by_type("german", "editorial", merge_tokens=False, kind="with_2bigrams")
article_texts_bi = article_data_bi["article_texts"]

# %%
vec_bi = Vectorizer.load('vectorizer/DEED_lda_german_editorial.pkl')
tm_bi = TopicModel.load('topic_models/lda/DEED_lda_german_editorial_articles_190.pkl')

# %%
labels_bi = tl.get_topic_lables([],article_texts_bi,None,vec_bi,tm_bi,n_cand_lables = 100,lable_min_df = 5, n_labels = 5)
# Out:
# shape topic model
# (190, 5239)
# pmishape
# (5239, 100)

# %%
display(hp.print_label_df(tm_bi,labels_bi))
# Out:
#                         0               1                  2              3  \
# Topic 0              tier          zeigen              video         filmen
# Topic 1               bio      bio-siegel         ökologisch        produkt
# Topic 2            gemüse            obst               ware      verkaufen
# Topic 3             weber  rudolf_steiner              eisen           paul
# Topic 4             honig            soja          brasilien          biene
# Topic 5          standard         lampert                bio   lebensmittel
# Topic 6              welt          online        schließlich            all
# Topic 7         biobauern            berg             europa       erklären
# Topic 8               kuh           weide            prozent          stall
# Topic 9           vorwurf          weisen        unternehmen         kritik
# Topic 10         frischen            pilz          vollmilch            süd
# ...

# %%
print("\nTopical labels:")
print("-" * 20)
for i, labels in enumerate(labels_bi):
    print(u"Topic {}: {}\n".format(
        i,
        ', '.join(map(lambda l: ' '.join(l), labels))
    ))
# Out:
# Topical labels:
# --------------------
# Topic 0: delia micklich, hans-wilhelm windhorst, coq vin, naturland-geschäftsführer steffen_reese, carola ketelhodt
#
# Topic 1: naturland-geschäftsführer steffen_reese, wolfram dienel, carola ketelhodt, benno schirrmeister, eu-agrarkommissarin mariann
#
# Topic 2: klostergut wiebrechtshausen, situationsbezogene vermarktungsstrategie, fernando krokisius, krokisius einkaufsmanager, mirjam hauser
#
# Topic 3: coq vin, hans-wilhelm windhorst, ansgar warner, pinot noir, carola ketelhodt
#
# Topic 4: benno schirrmeister, wolfram dienel, donald trump, coq vin, pinot noir
#
# Topic 5: gernot loitzl, benno schirrmeister, coq vin, wolfram dienel, eu-agrarkommissarin mariann
#
# Topic 6: benno schirrmeister, anke kähler, coq vin, carola ketelhodt, pinot noir
#
# Topic 7: eu-agrarkommissarin mariann, wolfram dienel, gernot loitzl, sri lanka, sde eliayahu
#
# ...
