# %%
import sys
sys.path.append('../..')
import src.data.data_loader as dl
from src.visualization import hlda_graph as hg
from src.models.sampler import HierarchicalLDA

# %% [markdown]
# #### Load German editorial texts

# %%
data = dl.get_articles_by_type("german","editorial")
texts = data["article_texts"]

# %%
doc_converted,vocab2 = hg.param_for_Hlda(texts)

# %% [markdown]
# #### Initialize Hlda parameters

# %% [markdown]
# ##### Hlda with 3 levels

# %%
n_samples = 100      # no of iterations for the sampler
alpha = 10          # smoothing over level distributions
gamma = 1.0           # CRP smoothing parameter; number of imaginary customers at next, as yet unused table
eta = 0.1             # smoothing over topic-word distributions
num_levels3 = 3        # the number of levels in the tree
display_topics = 10   # the number of iterations between printing a brief summary of the topics so far
n_words = 5           # the number of most probable words to print for each topic after model estimation
with_weights = False  # whether to print the words with the weights

#hlda3 = HierarchicalLDA(doc_converted, vocab2, alpha=alpha, gamma=gamma, eta=eta, num_levels=num_levels3, verbose=False)
#hlda3.estimate(n_samples, display_topics=display_topics, n_words=n_words, with_weights=with_weights)

# %%
dot3 = hg.graph(hlda3)
dot3.render("German Editorial 3 levels", view = True)

# %% [markdown]
# ##### Hlda with 5 levels

# %%
num_levels5 = 5

hlda5 = HierarchicalLDA(doc_converted, vocab2, alpha=alpha, gamma=gamma, eta=eta, num_levels=num_levels5, verbose=False)
hlda5.estimate(n_samples, display_topics=display_topics, n_words=n_words, with_weights=with_weights)
# Out:
# HierarchicalLDA sampling
#
# .......... 10
# topic=0 level=0 (documents=4730): bio, produkt, kunde, lebensmittel, euro,
#     topic=1 level=1 (documents=4515): tier, huhn, bauer, eiern, landwirtschaft,
#         topic=2 level=2 (documents=4312): produkt, prozent, verbraucher, bio, deutschland,
#             topic=3 level=3 (documents=4235): prozent, lebensmittel, produkt, landwirtschaft, pestizid,
#                 topic=4 level=4 (documents=4149): prozent, deutschland, konventionell, landwirtschaft, bauer,
#                 topic=14 level=4 (documents=10): wer­den, ber­lin, pro­duk­te, kön­nen, jah­ren,
#                 topic=24 level=4 (documents=23): brodowin, hennenberg, flade, naturschützer, schwertberg,
#                 topic=53 level=4 (documents=18): brunello, montalcino, starbucks, di, 13:05,
#                 topic=149 level=4 (documents=9): dole, ananas, eder, fernández, luis,
# ...

# %%
dot5 = hg.graph(hlda5)
dot5.render("German Editorial 4 levels", view = True)
# Out:
# 'German Editorial 4 levels.pdf'

# %% [markdown]
# ###### Hlda with 7 levels

# %%
num_levels7 = 7

hlda7 = HierarchicalLDA(doc_converted, vocab2, alpha=alpha, gamma=gamma, eta=eta, num_levels=num_levels7, verbose=False)
hlda7.estimate(n_samples, display_topics=display_topics, n_words=n_words, with_weights=with_weights)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-2162f65c0e32> in <module>()
#       1 num_levels7 = 7
#       2
# ----> 3 hlda7 = HierarchicalLDA(doc_converted, vocab2, alpha=alpha, gamma=gamma, eta=eta, num_levels=num_levels7, verbose=False)
#       4 hlda7.estimate(n_samples, display_topics=display_topics, n_words=n_words, with_weights=with_weights)
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\models\sampler.py in __init__(self, corpus, vocab, alpha, gamma, eta, seed, verbose, num_levels)
#     168                 # at each level, a node is selected by its parent node based on the CRP prior
#     169                 parent_node = path[level-1]
# --> 170                 level_node = parent_node.select(self.gamma)
#     171                 level_node.customers += 1
#     172                 path[level] = level_node
#
# ...

# %%
dot7 = hg.graph(hlda7)
dot7.render("German Editorial 5 levels", view = True)
