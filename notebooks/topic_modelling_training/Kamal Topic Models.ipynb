# %%
import sys
sys.path.append('../..')
import src.data.data_loader as dl
from src.features.vectorizer import Vectorizer
from src.models.topic_models import TopicModel
import pandas as pd
import sklearn.utils as skutil
pd.set_option('display.max_rows', None)

# %%
#### instead of this, add your comments
language = 'english'
typex = 'editorial'
data = dl.get_comments_by_type(language, typex,aggregate = "comments")
texts_editorial = data['comment_texts']

# %%
tm =TopicModel.load("topic_models/nmf/ENEDCO_nmf_english_editorial_comments_170.pkl")

# %%
vec = Vectorizer.load("vectorizer/ENEDCO_nmf_english_editorial.pkl")

# %%
display(tm.get_topics_dataframe())
# Out:
#                       0                 1             2             3  \
# Topic 0            food               eat        people          make
# Topic 1          amazon             foods         bezos         price
# Topic 2         organic      conventional     pesticide          usda
# Topic 3             gmo          monsanto          gene         label
# Topic 4          farmer            market       produce          sell
# Topic 5          animal              meat         vegan           eat
# Topic 6         chicken            animal           egg        humane
# Topic 7           /><br                br           />i             <
# Topic 8          direct             fresh        peapod        arrive
# Topic 9            milk               cow         dairy           raw
# Topic 10        natural              food         label           use
# Topic 11           wine         winemaker    biodynamic         grape
# ...

# %%
dtm = vec.get_document_token_matrix(texts_editorial)

# %%
dt = tm.get_document_topic_matrix(dtm,normalized=True)
# Out:
# Epoch 10 reached after 1.376 seconds, error: 153.538840
# Epoch 20 reached after 2.355 seconds, error: 153.495073
# Epoch 30 reached after 3.353 seconds, error: 153.489033
# Epoch 40 reached after 4.391 seconds, error: 153.487361
# Epoch 50 reached after 5.423 seconds, error: 153.486719
# Epoch 60 reached after 6.409 seconds, error: 153.486421
# Epoch 70 reached after 7.392 seconds, error: 153.486263
# Epoch 80 reached after 8.464 seconds, error: 153.486172
# Epoch 90 reached after 9.522 seconds, error: 153.486115
# Epoch 100 reached after 10.638 seconds, error: 153.486079
# Epoch 110 reached after 11.735 seconds, error: 153.486053
# Epoch 120 reached after 12.881 seconds, error: 153.486036
# Epoch 130 reached after 13.919 seconds, error: 153.486023
# Epoch 140 reached after 14.983 seconds, error: 153.486013
# Epoch 150 reached after 16.034 seconds, error: 153.486006
# Epoch 160 reached after 17.115 seconds, error: 153.486000
# ...

# %%
print(len(dt))
# Out:
# 26696
