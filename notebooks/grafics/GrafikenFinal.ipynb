# %%
import sys
sys.path.append('../..')
import src.data.data_loader as dl
from src.features.vectorizer import Vectorizer
from src.models.topic_models import TopicModel
import src.visualization.doc_topic_vis as vis
from collections import defaultdict
from collections import OrderedDict
import matplotlib.pyplot as plt
import numpy as np
# Out:
# C:\Users\Maria\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
model = "lda"
language = "german"
typetx = "editorial"
threshold = 0.1
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,190,sorted = True)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
#                           0               1                   2  \
# Topic 47            prozent          umsatz                euro
# Topic 111               bio      bioprodukt       konventionell
# Topic 43            produkt        regional               kunde
# Topic 152           prozent          hektar              fläche
# Topic 182              tier         schwein               stall
# Topic 90           mitglied         projekt      landwirtschaft
# Topic 145        österreich            wien      österreichisch
# Topic 54                hof       betreiben             familie
# Topic 107         kontrolle         behörde                fall
# Topic 83            schmidt           bauer         verbraucher
# Topic 1                 bio      bio-siegel          ökologisch
# Topic 116           prozent    lebensmittel            deutsche
# Topic 179             bauer            euro      landwirtschaft
# Topic 92              kunde          gemüse             angebot
# ...

# %%
model = "lda"
language = "german"
typetx = "editorial"
threshold = 0.3
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,190,sorted = True)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
#                        0               1                   2  \
# Topic 31           eiern        fipronil            belasten
# Topic 47         prozent          umsatz                euro
# Topic 152        prozent          hektar              fläche
# Topic 182           tier         schwein               stall
# Topic 118         studie        forscher          biologisch
# Topic 132       alnatura              dm                rehn
# Topic 183          eiern           küken               töten
# Topic 85         produkt            test  stiftung_warentest
# Topic 107      kontrolle         behörde                fall
# Topic 21     deutschland      löwenstein             deutsch
# Topic 81        pestizid       rückstand               probe
# Topic 130        italien           tonne                land
# Topic 179          bauer            euro      landwirtschaft
# Topic 178           fair         handeln             produkt
# ...

# %%
model = "lda"
language = "german"
typetx = "editorial"
threshold = 0.5
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,190,sorted = True)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
#                                0                1                   2  \
# Topic 31                   eiern         fipronil            belasten
# Topic 152                prozent           hektar              fläche
# Topic 118                 studie         forscher          biologisch
# Topic 130                italien            tonne                land
# Topic 85                 produkt             test  stiftung_warentest
# Topic 183                  eiern            küken               töten
# Topic 14           niedersachsen            meyer             betrieb
# Topic 15                   gurke      deutschland             spanien
# Topic 47                 prozent           umsatz                euro
# Topic 107              kontrolle          behörde                fall
# Topic 135                  eiern           ostern        bodenhaltung
# Topic 166                prozent           amazon           milliarde
# ...

# %%
model = "lda"
language = "english"
typetx = "editorial"
threshold = 0.1
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,190,sorted = True)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
#                     0             1             2                  3  \
# Topic 112      people         think          make               just
# Topic 83        study        health     pesticide       conventional
# Topic 82          eat       healthy        health               diet
# Topic 117     farming   agriculture          crop             farmer
# Topic 17       farmer         local          farm             market
# Topic 66        label       product       natural         ingredient
# Topic 104     company       product         brand               year
# Topic 46            $       percent          year               sale
# Topic 105       price             $          cost              foods
# Topic 114        farm        farmer       farming               crop
# Topic 23         grow        garden         plant               farm
# Topic 1       program          usda   agriculture               year
# Topic 109       foods       company         store              chain
# ...

# %%
model = "lda"
language = "english"
typetx = "editorial"
threshold = 0.3
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
#                  0            1            2             3            4  \
# Topic 83     study       health    pesticide  conventional     research
# Topic 82       eat      healthy       health          diet         good
# Topic 117  farming  agriculture         crop        farmer         soil
# Topic 120      gmo  genetically       modify          crop          non
# Topic 1    program         usda  agriculture          year     national
# Topic 46         $      percent         year          sale       market
# Topic 66     label      product      natural    ingredient          use
# Topic 109    foods      company        store         chain       market
# Topic 23      grow       garden        plant          farm    vegetable
# Topic 104  company      product        brand          year     business
# Topic 105    price            $         cost         foods        store
# Topic 123   amazon        foods        price             $      grocery
# ...

# %%
model = "lda"
language = "english"
typetx = "editorial"
threshold = 0.5
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,190,sorted = True)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
#                     0            1             2                3  \
# Topic 83        study       health     pesticide     conventional
# Topic 117     farming  agriculture          crop           farmer
# Topic 123      amazon        foods         price                $
# Topic 1       program         usda   agriculture             year
# Topic 21          fda         test          rice            level
# Topic 77         milk        dairy           cow             usda
# Topic 82          eat      healthy        health             diet
# Topic 46            $      percent          year             sale
# Topic 66        label      product       natural       ingredient
# Topic 8      labeling        label           gmo              law
# Topic 16       worker         work          fair             farm
# Topic 23         grow       garden         plant             farm
# Topic 34       animal         farm         raise          pasture
# ...

# %%
model = "nmf"
language = "german"
typetx = "editorial"
threshold = 0.1
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
# Epoch 10 reached after 0.638 seconds, error: 63.547208
# Epoch 20 reached after 0.952 seconds, error: 63.536450
# Epoch 30 reached after 1.266 seconds, error: 63.534955
# Epoch 40 reached after 1.581 seconds, error: 63.534535
# Epoch 50 reached after 1.889 seconds, error: 63.534373
# Epoch 60 reached after 2.210 seconds, error: 63.534297
# Epoch 70 reached after 2.515 seconds, error: 63.534257
# Epoch 80 reached after 2.835 seconds, error: 63.534233
# Epoch 90 reached after 3.157 seconds, error: 63.534218
# Epoch 100 reached after 3.468 seconds, error: 63.534209
# Epoch 110 reached after 3.798 seconds, error: 63.534202
# Epoch 120 reached after 4.116 seconds, error: 63.534198
# Epoch 130 reached after 4.412 seconds, error: 63.534194
# Epoch 140 reached after 4.739 seconds, error: 63.534192
# Epoch 150 reached after 5.056 seconds, error: 63.534190
# Epoch 160 reached after 5.360 seconds, error: 63.534188
# Epoch 170 reached after 5.677 seconds, error: 63.534187
# ...

# %%
model = "nmf"
language = "german"
typetx = "editorial"
threshold = 0.3
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
# Epoch 10 reached after 0.684 seconds, error: 63.547208
# Epoch 20 reached after 1.016 seconds, error: 63.536450
# Epoch 30 reached after 1.349 seconds, error: 63.534955
# Epoch 40 reached after 1.690 seconds, error: 63.534535
# Epoch 50 reached after 2.014 seconds, error: 63.534373
# Epoch 60 reached after 2.328 seconds, error: 63.534297
# Epoch 70 reached after 2.732 seconds, error: 63.534257
# Epoch 80 reached after 3.107 seconds, error: 63.534233
# Epoch 90 reached after 3.443 seconds, error: 63.534218
# Epoch 100 reached after 3.828 seconds, error: 63.534209
# Epoch 110 reached after 4.150 seconds, error: 63.534202
# Epoch 120 reached after 4.471 seconds, error: 63.534198
# Epoch 130 reached after 4.788 seconds, error: 63.534194
# Epoch 140 reached after 5.111 seconds, error: 63.534192
# Epoch 150 reached after 5.480 seconds, error: 63.534190
# Epoch 160 reached after 5.837 seconds, error: 63.534188
# Epoch 170 reached after 6.186 seconds, error: 63.534187
# ...

# %%
model = "nmf"
language = "german"
typetx = "editorial"
threshold = 0.5
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,190,sorted = True)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
# Epoch 10 reached after 0.692 seconds, error: 63.547208
# Epoch 20 reached after 1.062 seconds, error: 63.536450
# Epoch 30 reached after 1.516 seconds, error: 63.534955
# Epoch 40 reached after 1.888 seconds, error: 63.534535
# Epoch 50 reached after 2.280 seconds, error: 63.534373
# Epoch 60 reached after 2.614 seconds, error: 63.534297
# Epoch 70 reached after 2.957 seconds, error: 63.534257
# Epoch 80 reached after 3.333 seconds, error: 63.534233
# Epoch 90 reached after 3.669 seconds, error: 63.534218
# Epoch 100 reached after 4.004 seconds, error: 63.534209
# Epoch 110 reached after 4.377 seconds, error: 63.534202
# Epoch 120 reached after 4.690 seconds, error: 63.534198
# Epoch 130 reached after 5.013 seconds, error: 63.534194
# Epoch 140 reached after 5.333 seconds, error: 63.534192
# Epoch 150 reached after 5.642 seconds, error: 63.534190
# Epoch 160 reached after 6.000 seconds, error: 63.534188
# Epoch 170 reached after 6.335 seconds, error: 63.534187
# ...

# %%
model = "nmf"
language = "english"
typetx = "editorial"
threshold = 0.1
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
# Epoch 10 reached after 0.452 seconds, error: 42.440931
# Epoch 20 reached after 0.677 seconds, error: 42.392839
# Epoch 30 reached after 0.911 seconds, error: 42.385035
# Epoch 40 reached after 1.126 seconds, error: 42.382705
# Epoch 50 reached after 1.325 seconds, error: 42.381772
# Epoch 60 reached after 1.529 seconds, error: 42.381326
# Epoch 70 reached after 1.747 seconds, error: 42.381086
# Epoch 80 reached after 1.980 seconds, error: 42.380945
# Epoch 90 reached after 2.200 seconds, error: 42.380857
# Epoch 100 reached after 2.406 seconds, error: 42.380799
# Epoch 110 reached after 2.622 seconds, error: 42.380759
# Epoch 120 reached after 2.837 seconds, error: 42.380731
# Epoch 130 reached after 3.044 seconds, error: 42.380710
# Epoch 140 reached after 3.258 seconds, error: 42.380694
# Epoch 150 reached after 3.463 seconds, error: 42.380683
# Epoch 160 reached after 3.687 seconds, error: 42.380674
# Epoch 170 reached after 3.897 seconds, error: 42.380666
# ...

# %%
model = "nmf"
language = "english"
typetx = "editorial"
threshold = 0.3
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
# Epoch 10 reached after 0.631 seconds, error: 42.440931
# Epoch 20 reached after 0.898 seconds, error: 42.392839
# Epoch 30 reached after 1.145 seconds, error: 42.385035
# Epoch 40 reached after 1.449 seconds, error: 42.382705
# Epoch 50 reached after 1.718 seconds, error: 42.381772
# Epoch 60 reached after 1.980 seconds, error: 42.381326
# Epoch 70 reached after 2.278 seconds, error: 42.381086
# Epoch 80 reached after 2.621 seconds, error: 42.380945
# Epoch 90 reached after 2.880 seconds, error: 42.380857
# Epoch 100 reached after 3.152 seconds, error: 42.380799
# Epoch 110 reached after 3.398 seconds, error: 42.380759
# Epoch 120 reached after 3.705 seconds, error: 42.380731
# Epoch 130 reached after 3.929 seconds, error: 42.380710
# Epoch 140 reached after 4.151 seconds, error: 42.380694
# Epoch 150 reached after 4.346 seconds, error: 42.380683
# Epoch 160 reached after 4.551 seconds, error: 42.380674
# Epoch 170 reached after 4.789 seconds, error: 42.380666
# ...

# %%
model = "nmf"
language = "english"
typetx = "editorial"
threshold = 0.5
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,190,sorted = True)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
# Epoch 10 reached after 0.485 seconds, error: 42.440931
# Epoch 20 reached after 0.704 seconds, error: 42.392839
# Epoch 30 reached after 0.931 seconds, error: 42.385035
# Epoch 40 reached after 1.180 seconds, error: 42.382705
# Epoch 50 reached after 1.454 seconds, error: 42.381772
# Epoch 60 reached after 1.666 seconds, error: 42.381326
# Epoch 70 reached after 1.866 seconds, error: 42.381086
# Epoch 80 reached after 2.110 seconds, error: 42.380945
# Epoch 90 reached after 2.371 seconds, error: 42.380857
# Epoch 100 reached after 2.580 seconds, error: 42.380799
# Epoch 110 reached after 2.785 seconds, error: 42.380759
# Epoch 120 reached after 2.989 seconds, error: 42.380731
# Epoch 130 reached after 3.184 seconds, error: 42.380710
# Epoch 140 reached after 3.389 seconds, error: 42.380694
# Epoch 150 reached after 3.580 seconds, error: 42.380683
# Epoch 160 reached after 3.783 seconds, error: 42.380674
# Epoch 170 reached after 4.002 seconds, error: 42.380666
# ...

# %%
model = "nmf"
language = "german"
typetx = "editorial"
threshold = 0.1
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
# Epoch 10 reached after 0.635 seconds, error: 63.547208
# Epoch 20 reached after 0.969 seconds, error: 63.536450
# Epoch 30 reached after 1.275 seconds, error: 63.534955
# Epoch 40 reached after 1.602 seconds, error: 63.534535
# Epoch 50 reached after 1.926 seconds, error: 63.534373
# Epoch 60 reached after 2.235 seconds, error: 63.534297
# Epoch 70 reached after 2.534 seconds, error: 63.534257
# Epoch 80 reached after 2.842 seconds, error: 63.534233
# Epoch 90 reached after 3.158 seconds, error: 63.534218
# Epoch 100 reached after 3.476 seconds, error: 63.534209
# Epoch 110 reached after 3.783 seconds, error: 63.534202
# Epoch 120 reached after 4.108 seconds, error: 63.534198
# Epoch 130 reached after 4.522 seconds, error: 63.534194
# Epoch 140 reached after 4.918 seconds, error: 63.534192
# Epoch 150 reached after 5.342 seconds, error: 63.534190
# Epoch 160 reached after 5.665 seconds, error: 63.534188
# Epoch 170 reached after 5.993 seconds, error: 63.534187
# ...

# %%
model = "nmf"
language = "german"
typetx = "editorial"
threshold = 0.3
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
# Epoch 10 reached after 0.636 seconds, error: 63.547208
# Epoch 20 reached after 0.948 seconds, error: 63.536450
# Epoch 30 reached after 1.341 seconds, error: 63.534955
# Epoch 40 reached after 1.682 seconds, error: 63.534535
# Epoch 50 reached after 2.005 seconds, error: 63.534373
# Epoch 60 reached after 2.337 seconds, error: 63.534297
# Epoch 70 reached after 2.736 seconds, error: 63.534257
# Epoch 80 reached after 3.111 seconds, error: 63.534233
# Epoch 90 reached after 3.503 seconds, error: 63.534218
# Epoch 100 reached after 3.825 seconds, error: 63.534209
# Epoch 110 reached after 4.200 seconds, error: 63.534202
# Epoch 120 reached after 4.508 seconds, error: 63.534198
# Epoch 130 reached after 4.832 seconds, error: 63.534194
# Epoch 140 reached after 5.140 seconds, error: 63.534192
# Epoch 150 reached after 5.449 seconds, error: 63.534190
# Epoch 160 reached after 5.773 seconds, error: 63.534188
# Epoch 170 reached after 6.078 seconds, error: 63.534187
# ...

# %%
model = "nmf"
language = "german"
typetx = "editorial"
threshold = 0.5
x_limit =20

document_topic_matrix,topicmodel = vis.get_document_topic_matrix(model, language, typetx)
k, v = vis.amount_topic_per_dokument(threshold, document_topic_matrix)
vis.plot_amount_topic_per_document(model,language,typetx,threshold, k, v)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit, sorted = False)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,190,sorted = True)
vis.plot_amount_doc_per_topic(model,language,typetx,topicmodel,threshold, document_topic_matrix,x_limit,sorted = True)
# Out:
# Epoch 10 reached after 0.715 seconds, error: 63.547208
# Epoch 20 reached after 1.039 seconds, error: 63.536450
# Epoch 30 reached after 1.348 seconds, error: 63.534955
# Epoch 40 reached after 1.668 seconds, error: 63.534535
# Epoch 50 reached after 1.957 seconds, error: 63.534373
# Epoch 60 reached after 2.248 seconds, error: 63.534297
# Epoch 70 reached after 2.556 seconds, error: 63.534257
# Epoch 80 reached after 2.855 seconds, error: 63.534233
# Epoch 90 reached after 3.168 seconds, error: 63.534218
# Epoch 100 reached after 3.487 seconds, error: 63.534209
# Epoch 110 reached after 3.788 seconds, error: 63.534202
# Epoch 120 reached after 4.087 seconds, error: 63.534198
# Epoch 130 reached after 4.403 seconds, error: 63.534194
# Epoch 140 reached after 4.715 seconds, error: 63.534192
# Epoch 150 reached after 5.018 seconds, error: 63.534190
# Epoch 160 reached after 5.332 seconds, error: 63.534188
# Epoch 170 reached after 5.643 seconds, error: 63.534187
# ...
