# %%
import sys
sys.path.append('../..')
import src.Automatic_Topic_Labeling.lable_topic as tl
import src.Automatic_Topic_Labeling.helper_functions as hp
import src.data.data_loader as dl
from src.features.vectorizer import Vectorizer
from src.models.topic_models import TopicModel
# Out:
# C:\Users\Maria\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English

# %%
language = "german"
type = "editorial"
texttype = "article_texts"
model = "lda"
pos = None

docs = hp.load_doc(language, type, texttype,"with_2bigramms")

print(docs[:5])
vec = Vectorizer.load('vectorizer/DEED_lda_german_editorial.pkl')
tm = TopicModel.load('topic_models/lda/DEED_lda_german_editorial_articles_190.pkl')


print(docs[:5])
# Out:
# [['verdacht', 'hegen', 'experte', 'europäische_union', 'liegen', 'beweisen', 'bio-obst_-gemüse', 'israelisch', 'siedlung', 'besetzen', 'westjordanland', 'golanhöhen', 'stammen', 'häufig', 'falsch', 'deklarieren', 'ware', 'made', 'israel', 'exportieren', 'lebensmittel-', 'veterinäramt', 'brüssel', 'kontrolle', 'ort', 'eindeutig', 'beweisen', 'sichern', 'heißen', 'intern', 'kommissionsbericht', 'israelisch', 'behörde', 'reden', 'stellen', 'made', 'israel', 'exporteure', 'laut', 'anweisung', 'eu-kommission', 'ware', 'deklarieren', 'innerhalb', 'international', 'anerkannt', 'grenze', 'staat', 'israel', 'produzieren', 'teilen', 'mitgliedstaaten', 'israelische', 'zertifizierung', 'bio-produkten', 'akzeptieren', 'februar', 'mitgliedstaaten', 'etikettenschwindel', 'verantworten', 'meist', 'land', 'eu-direktive', 'anschließen', 'landwirtschaftsministerium', 'berlin', 'erklären', 'bio-produkte', 'müssten', 'herkunftshinweis', 'besetzt', 'palästinensische', 'gebieten', 'tragen', 'verkaufen', 'hinderlich'], ['berliner', 'onlinelieferdienst', 'bonativo', 'vertreiben', 'bio-lebensmittel', 'gesetzlich', 'nötig', 'bio-zertifizierung', 'geschäftsführer', 'christian', 'eggert', 'räumen', 'lediglich', 'kontakt', 'kontrollfirmen', 'prozess', 'zertifizierung', 'beginnen', 'unternehmen', 'bio-zulassung', 'verkaufen', 'start', 'januar', 'gebrauchen', 'kurzem', 'oberlandesgericht_frankfurt', 'zertifizierungspflicht', 'onlinehandel', 'urteilen', 'bestätigen', 'bonativo', 'stehen', 'rocket', 'internet', 'beteiligungsgesellschaft', 'samwer-brüder', 'anteil', 'knapp', 'prozent', 'zahlen', 'tengelmann', 'kürzlich', 'million', 'euro', 'bringdienst', 'demnach', 'fast', 'million', 'euro', 'wert'], ['lidl-schwester', 'kaufland', 'werben', 'umstritten', 'signet', 'produkt', 'baden-württemberg', 'staatsministerium', 'schauen', 'maultaschen', 'knabberbrezeln', 'hochzeitsnudeln', 'schwabe', 'greifen', 'supermarkt', 'produkt', 'tatsächlich', 'region', 'produzieren', 'regal', 'handelskette', 'kaufland', 'finden', 'ware', 'hinweis', 'qualität', 'baden-württemberg', 'locken', 'preisschild', 'prangen', 'ovales', 'logo', 'gelbe', 'landeswappen', 'staufer-löwen', 'erinnern', 'blicken', 'gütesiegel', 'aussehen', 'wahrheit', 'mogelpackung', 'sogenannt', 'baden-württemberg-signet', 'letztlich', 'jed', 'stolze', 'bürgern', 'verwenden', 'verbundenheit', 'ländle', 'demonstrieren', 'beispielsweise', 'ehrenamtlich', 'verein', 'verbinden', 'mitunter', 'partei', 'nutzen', 'zusammenhang', 'lebensmittel', 'bauernbratwurst', 'weizenmehl', 'suggerieren', 'zeichen', 'verbraucher', 'irgendwie', 'geartet', 'qualitätskontrolle', 'land', 'klaren', 'regeln', 'signet', 'markenmäßiger', 'herkunftsnachweis', 'verwenden', 'internetseite', 'landesregierung', 'heißen', 'kaufland', 'tochtergesellschaft', 'mächtig', 'schwarz-gruppe', 'gelten', 'offenbaren', 'regel', 'gruppe', 'discounter', 'lidl', 'neckarsulm', 'viertgrößte', 'lebensmittelhändler', 'welt', 'jahresumsatz', 'milliarde', 'euro', 'lidl-gründer', 'dieter', 'schwarz', 'spendabel', 'mäzen', 'land', 'privat', 'stiftung', 'mehrer', 'million', 'euro', 'überwiegen', 'projekt', 'heimat', 'regional', 'lebensmittel', 'bio-boom', 'trend', 'handeln', 'gefühl', 'greifen', 'regal', 'indirekt', 'bauer', 'heimat', 'unterstützen', 'lässt', 'großstädter', 'entsprechen', 'gekennzeichnet', 'produkt', 'greifen', 'werbung', 'regionalität', 'produkt', 'finden', 'anbieter', 'bar', 'geld', 'wert', 'erklären', 'klaus', 'müller', 'bundesverband', 'verbraucherzentrale', 'klarheit', 'wahrheit', 'leider', 'organisation', 'foodwatch', 'fordern', 'klaren', 'gesetzliche', 'regelung', 'regionalität', 'werben', 'beschwerde', 'wilde', 'verwendung', 'baden-württemberg-signets', 'kaufland', 'meist', 'fragen', 'verwirren', 'verbraucher', 'innen-', 'verbraucherschutzministerium', 'qualität', 'baden-württemberg', 'bürge', 'edeka-', 'norma-', 'rewe-märkte', 'erhalten', 'daraufhin', 'mahnend', 'post', 'stuttgarter', 'staatsministerium', 'stellen', 'werbung', 'landes-logo', 'sc ...
# [['verdacht', 'hegen', 'experte', 'europäische_union', 'liegen', 'beweisen', 'bio-obst_-gemüse', 'israelisch', 'siedlung', 'besetzen', 'westjordanland', 'golanhöhen', 'stammen', 'häufig', 'falsch', 'deklarieren', 'ware', 'made', 'israel', 'exportieren', 'lebensmittel-', 'veterinäramt', 'brüssel', 'kontrolle', 'ort', 'eindeutig', 'beweisen', 'sichern', 'heißen', 'intern', 'kommissionsbericht', 'israelisch', 'behörde', 'reden', 'stellen', 'made', 'israel', 'exporteure', 'laut', 'anweisung', 'eu-kommission', 'ware', 'deklarieren', 'innerhalb', 'international', 'anerkannt', 'grenze', 'staat', 'israel', 'produzieren', 'teilen', 'mitgliedstaaten', 'israelische', 'zertifizierung', 'bio-produkten', 'akzeptieren', 'februar', 'mitgliedstaaten', 'etikettenschwindel', 'verantworten', 'meist', 'land', 'eu-direktive', 'anschließen', 'landwirtschaftsministerium', 'berlin', 'erklären', 'bio-produkte', 'müssten', 'herkunftshinweis', 'besetzt', 'palästinensische', 'gebieten', 'tragen', 'verkaufen', 'hinderlich'], ['berliner', 'onlinelieferdienst', 'bonativo', 'vertreiben', 'bio-lebensmittel', 'gesetzlich', 'nötig', 'bio-zertifizierung', 'geschäftsführer', 'christian', 'eggert', 'räumen', 'lediglich', 'kontakt', 'kontrollfirmen', 'prozess', 'zertifizierung', 'beginnen', 'unternehmen', 'bio-zulassung', 'verkaufen', 'start', 'januar', 'gebrauchen', 'kurzem', 'oberlandesgericht_frankfurt', 'zertifizierungspflicht', 'onlinehandel', 'urteilen', 'bestätigen', 'bonativo', 'stehen', 'rocket', 'internet', 'beteiligungsgesellschaft', 'samwer-brüder', 'anteil', 'knapp', 'prozent', 'zahlen', 'tengelmann', 'kürzlich', 'million', 'euro', 'bringdienst', 'demnach', 'fast', 'million', 'euro', 'wert'], ['lidl-schwester', 'kaufland', 'werben', 'umstritten', 'signet', 'produkt', 'baden-württemberg', 'staatsministerium', 'schauen', 'maultaschen', 'knabberbrezeln', 'hochzeitsnudeln', 'schwabe', 'greifen', 'supermarkt', 'produkt', 'tatsächlich', 'region', 'produzieren', 'regal', 'handelskette', 'kaufland', 'finden', 'ware', 'hinweis', 'qualität', 'baden-württemberg', 'locken', 'preisschild', 'prangen', 'ovales', 'logo', 'gelbe', 'landeswappen', 'staufer-löwen', 'erinnern', 'blicken', 'gütesiegel', 'aussehen', 'wahrheit', 'mogelpackung', 'sogenannt', 'baden-württemberg-signet', 'letztlich', 'jed', 'stolze', 'bürgern', 'verwenden', 'verbundenheit', 'ländle', 'demonstrieren', 'beispielsweise', 'ehrenamtlich', 'verein', 'verbinden', 'mitunter', 'partei', 'nutzen', 'zusammenhang', 'lebensmittel', 'bauernbratwurst', 'weizenmehl', 'suggerieren', 'zeichen', 'verbraucher', 'irgendwie', 'geartet', 'qualitätskontrolle', 'land', 'klaren', 'regeln', 'signet', 'markenmäßiger', 'herkunftsnachweis', 'verwenden', 'internetseite', 'landesregierung', 'heißen', 'kaufland', 'tochtergesellschaft', 'mächtig', 'schwarz-gruppe', 'gelten', 'offenbaren', 'regel', 'gruppe', 'discounter', 'lidl', 'neckarsulm', 'viertgrößte', 'lebensmittelhändler', 'welt', 'jahresumsatz', 'milliarde', 'euro', 'lidl-gründer', 'dieter', 'schwarz', 'spendabel', 'mäzen', 'land', 'privat', 'stiftung', 'mehrer', 'million', 'euro', 'überwiegen', 'projekt', 'heimat', 'regional', 'lebensmittel', 'bio-boom', 'trend', 'handeln', 'gefühl', 'greifen', 'regal', 'indirekt', 'bauer', 'heimat', 'unterstützen', 'lässt', 'großstädter', 'entsprechen', 'gekennzeichnet', 'produkt', 'greifen', 'werbung', 'regionalität', 'produkt', 'finden', 'anbieter', 'bar', 'geld', 'wert', 'erklären', 'klaus', 'müller', 'bundesverband', 'verbraucherzentrale', 'klarheit', 'wahrheit', 'leider', 'organisation', 'foodwatch', 'fordern', 'klaren', 'gesetzliche', 'regelung', 'regionalität', 'werben', 'beschwerde', 'wilde', 'verwendung', 'baden-württemberg-signets', 'kaufland', 'meist', 'fragen', 'verwirren', 'verbraucher', 'innen-', 'verbraucherschutzministerium', 'qualität', 'baden-württemberg', 'bürge', 'edeka-', 'norma-', 'rewe-märkte', 'erhalten', 'daraufhin', 'mahnend', 'post', 'stuttgarter', 'staatsministerium', 'stellen', 'werbung', 'landes-logo', 'sc ...

# %%
labels = tl.get_topic_lables([],docs,pos,model,vec,tm,n_top_words = 15, n_cand_lables = 100,lable_min_df = 5, n_labels = 8)
print("\nTopical labels:")
print("-" * 20)
for i, labels in enumerate(labels):
    print(u"Topic {}: {}\n".format(
        i,
        ', '.join(map(lambda l: ' '.join(l), labels))
    ))
# Out:
# PMI[[ 2.25712272  1.38165398  2.25712272 ...  1.36786066  2.25712272
#    2.25712272]
#  [ 2.04005821  1.16458948  2.04005821 ...  1.15079615  2.04005821
#    2.04005821]
#  [ 2.38633445  1.51086571  2.38633445 ...  1.49707239  2.38633445
#    2.38633445]
#  ...
#  [ 2.19828222  1.32281348  2.8914294  ...  1.30902016  2.19828222
#    2.19828222]
#  [ 1.1737779  -0.39483802  1.1737779  ... -0.40863134  0.48063072
#    0.48063072]
#  [ 2.8091913   1.24057538  2.8091913  ...  1.22678206  2.11604412
#    2.11604412]]
# Topic modeling using lda
#                         0               1                  2              3  \
# Topic 0              tier          zeigen              video         filmen
# Topic 1               bio      bio-siegel         ökologisch        produkt
# Topic 2            gemüse            obst               ware      verkaufen
# Topic 3             weber  rudolf_steiner              eisen           paul
# Topic 4             honig            soja          brasilien          biene
# Topic 5          standard         lampert                bio   lebensmittel
# Topic 6              welt          online        schließlich            all
# Topic 7         biobauern            berg             europa       erklären
# Topic 8               kuh           weide            prozent          stall
# Topic 9           vorwurf          weisen        unternehmen         kritik
# Topic 10         frischen            pilz          vollmilch            süd
# Topic 11   landwirtschaft             hof              bauer            jed
# Topic 12            grüne            grün             partei            all
# Topic 13          wienern         praktik   tierschutzgesetz         nächst
# Topic 14    niedersachsen           meyer            betrieb      christian
# Topic 15            gurke     deutschland            spanien        deutsch
# Topic 16      unternehmen     mitarbeiter               euro          firma
# Topic 17         alnatura           klage                 dm      götz_rehn
# Topic 18          bioland      ökologisch            demeter      naturland
# Topic 19             ware         produkt          verkaufen   lebensmittel
# Topic 20             gast      restaurant        gastronomie          küche
# Topic 21      deutschland      löwenstein            deutsch       nürnberg
# Topic 22         johannes           biene           pestizid       maschine
# Topic 23            sorte             alt           vielfalt          markt
# Topic 24          plastik       verpacken  baden-württemberg     supermarkt
# Topic 25              bio         bleiben           mehrheit          knapp
# Topic 26            bauer            feld          biobauern       landwirt
# Topic 27       wirtschaft     unternehmen     großbritannien         verein
# Topic 28         eröffnen         filiale           geschäft            neu
# Topic 29           aigner          dioxin            futtern   futtermittel
# ...                   ...             ...                ...            ...
# Topic 160       friedrich         franzen     öko-verordnung        himmeln
# Topic 161          kupfer          listen       schwermetall        prozent
# Topic 162         siegeln           label          kriterium     initiative
# Topic 163         gestern        gemeinde           vorhaben    bio-landbau
# Topic 164   naturkosmetik        kosmetik            produkt  inhaltsstoffe
# Topic 165           lachs            glas             gesamt   artgerechten
# Topic 166         prozent          amazon          milliarde        betonen
# Topic 167            grün       biosiegel        deutschland        problem
# Topic 168          keimen        bakterie               keim    salmonellen
# Topic 169   konventionell      ökologisch     konventionelle            bio
# Topic 170      ökologisch         hamburg         agrarwende        bündnis
# Topic 171         artikel          kaufen             kirche      kaufpreis
# Topic 172       glyphosat       zulassung                bfr            pro
# Topic 173            frau             bio              natur        platzen
# Topic 174       vierbauch          buchen          konsument         obmann
# Topic 175          hektar          ernten            anbauen       landwirt
# Topic 176          dioxin       grenzwert           belasten        verzehr
# Topic 177          müller          halten              boden        holland
# Topic 178            fair         handeln            produkt         kaffee
# Topic 179           bauer            euro     landwirtschaft           geld
# Topic 180          berlin     brandenburg           berliner  brandenburger
# Topic 181  landwirtschaft      nachhaltig           weltweit          bauer
# Topic 182            tier         schwein              stall        fleisch
# Topic 183           eiern           küken              töten           tier
# Topic 184            mark      eigenmarke    supermarktkette           rewe
# Topic 185           apfel           birne              braun        bioland
# Topic 186           essen    lebensmittel          ernährung         gesund
# Topic 187           biene          insekt        verbraucher            jed
# Topic 188             bio      biolandbau       lebensmittel        prozent
# Topic 189       verwenden       angeboten            derzeit     bio-gemüse
#
#                           4                     5                   6  \
# Topic 0             zustand                 huber                bild
# Topic 1             siegeln            biologisch             stammen
# Topic 2             handeln               produkt               kunde
# Topic 3             demeter                hallen       schwierigkeit
# Topic 4              imkern           deutschland                 wwf
# Topic 5           konsument               preisen          österreich
# Topic 6              stehen                  rest          ökologisch
# Topic 7           kilometer             konsument   supermarktregalen
# Topic 8      landwirtschaft                 bauer                horn
# Topic 9              falsch                  fall                peta
# Topic 10               nord                   bio            anbieter
# Topic 11            stellen                  hand            arbeiten
# Topic 12            bleiben                heißen               thema
# Topic 13             landen      niederösterreich              feiern
# Topic 14           bio-eier    staatsanwaltschaft             million
# Topic 15           spanisch               behörde             hamburg
# Topic 16        deutschland                    's              zahlen
# Topic 17               früh               prozess            streiten
# Topic 18         richtlinie                streng            erlauben
# Topic 19               land                   bio             prozent
# Topic 20                bio                kochen             täglich
# Topic 21               euro             milliarde             biofach
# Topic 22           forscher              chemisch           sogenannt
# Topic 23             finden               bringen              üblich
# Topic 24             gemüse          lebensmittel             produkt
# Topic 25              döner                   pro          produktion
# Topic 26           biobauer                fläche       konventionell
# Topic 27               ttip              monsanto          europäisch
# Topic 28           standort                 kunde           sortiment
# Topic 29              woche               skandal      dioxin-skandal
# ...                     ...                   ...                 ...
# Topic 160  massenproduktion                 fuchs              stehen
# Topic 161            gemüse               mitteln  forschungsinstitut
# Topic 162          standard            gesetzlich             neuland
# Topic 163            daniel        landwirtschaft         bevölkerung
# Topic 164             hauen                 julia              kaufen
# Topic 165           student  konservierungsstoffe          ökologisch
# Topic 166            dollar                   usa           naturkost
# Topic 167            lassen           verbraucher             stellen
# Topic 168         infektion             resistent             erreger
# Topic 169        produktion              erzeugen      landwirtschaft
# Topic 170           fördern                zielen                 fao
# Topic 171             rufen             erstatten              heißen
# Topic 172             stoff                  bier          mikrogramm
# Topic 173             mitte                stehen              füllen
# Topic 174       förderungen                   bio               weiss
# Topic 175           wachsen                   mai                feld
# Topic 176              gift           verbraucher          gefährlich
# Topic 177            stehen               problem               sehen
# Topic 178    fair_gehandelt             fairtrade              banane
# Topic 179          landwirt            subvention           milliarde
# Topic 180   brandenburgisch                umland  berlin-brandenburg
# Topic 181      lebensmittel                     ■           milliarde
# Topic 182       tierhaltung                halten   massentierhaltung
# Topic 183           fleisch                 legen           legehenne
# Topic 184       kooperation            österreich              bieten
# Topic 185           übersee            ökolandbau              stehen
# Topic 186            kochen                  kind            ernähren
# Topic 187         kommentar              landwirt            schaffen
# Topic 188             krise                   öko               bauer
# Topic 189          anfragen               produkt            aufgrund
#
#                            7                8                   9
# Topic 0            aufnehmen              tot                huhn
# Topic 1         bio-produkte           streng             demeter
# Topic 2             aussehen            möhre             perfekt
# Topic 3            einziehen         beweisen  anthroposophischen
# Topic 4             weltweit       südamerika             problem
# Topic 5             qualität          produkt               sehen
# Topic 6               finden           nehmen            bisschen
# Topic 7          gemüseanbau          produkt             genügen
# Topic 8            milchkühe             kalb             deutsch
# Topic 9                 laut         vereinen             anzeige
# Topic 10               milch   landwirtschaft                land
# Topic 11                 neu            leben               sehen
# Topic 12   massentierhaltung       politische           versuchen
# Topic 13       rechtfertigen         eröffnen              kochen
# Topic 14              betrug       ermittlung           ermitteln
# Topic 15              gemüse        hamburger            erklären
# Topic 16             million           umsatz         unternehmer
# Topic 17             gründer         beginnen         unternehmen
# Topic 18                tier          deutsch             verband
# Topic 19           produzent      deutschland            bio-ware
# Topic 20           verwenden          gericht           schmecken
# Topic 21    bund_ökologische       ökologisch                land
# Topic 22           schreiten         mithilfe               blüte
# Topic 23               sehen              all           geschmack
# Topic 24                 öko             obst         haltbarkeit
# Topic 25             problem      herkömmlich     ferienwohnungen
# Topic 26              hektar           ernten           bio-bauer
# Topic 27         transparent          konzern         transparenz
# Topic 28           verkaufen            markt                lade
# Topic 29     harles_jentzsch            tonne             fordern
# ...                      ...              ...                 ...
# Topic 160             regeln             frei               sehen
# Topic 161           spritzen       gesetzlich           verbieten
# Topic 162                neu      verbraucher              siegel
# Topic 163             planen      genehmigung          biologisch
# Topic 164              frank         allergie             deutsch
# Topic 165              peter    geschmacklich             futtern
# Topic 166        whole_foods            stark   bio-lebensmitteln
# Topic 167               dirk             eher                land
# Topic 168       lebensmittel       gefährlich                fall
# Topic 169              klima           umwelt         produzieren
# Topic 170       lebensmittel  agrarwirtschaft      landwirtschaft
# Topic 171           mittwoch            welch             genannt
# Topic 172          grenzwert           studie        unbedenklich
# Topic 173         teilnehmer            letzt           entfernen
# Topic 174            bereich       wesentlich               bauer
# Topic 175           getreide        kartoffel               acker
# Topic 176      überschreiten          behörde                akut
# Topic 177          lieferant           schwer              suchen
# Topic 178              faire             ware             siegeln
# Topic 179            prozent               eu        agrarpolitik
# Topic 180              wende          kirsche                laut
# Topic 181             global        bäuerlich         produzieren
# Topic 182            haltung          platzen                rind
# Topic 183               hahn          million      männlich_küken
# Topic 184         vertreiben           heißen               enden
# Topic 185          bio-äpfel          deutsch                 neu
# Topic 186                bio              jed              teller
# Topic 187     landwirtschaft            bauer              imkern
# Topic 188          ideologie             welt              müsste
# Topic 189           november             käse           antworten
#
# [190 rows x 10 columns]
# shape topic model
# (190, 5239)
# pmishape
# (5222, 100)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-ff476c69109c> in <module>()
#       1
# ----> 2 labels = tl.get_topic_lables([],docs,[],model,vec,tm,n_top_words = 15, n_cand_lables = 100,lable_min_df = 15, n_labels = 8)
#       3 print("\nTopical labels:")
#       4 print("-" * 20)
#       5 for i, labels in enumerate(labels):
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\lable_topic.py in get_topic_lables(tagged_docs, docs, pos, model, vec, trained_tm, n_top_words, n_cand_lables, lable_min_df, n_labels)
#      86                                index2label=pmi_cal.index2label_,
#      87                                label_models=None,
# ---> 88                                k = n_labels)
#      89     return labels
#      90
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in top_k_labels(self, topic_models, pmi_w2l, index2label, label_models, k)
#     212         label_scores = self.combined_label_score(topic_models, pmi_w2l,
#     213                                                  self._discrimination,
# --> 214                                                  self._mu)
#     215
#     216         print("lable scores")
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in combined_label_score(self, topic_models, pmi_w2l, use_discrimination, mu)
#     147             score for each topic and label pair
#     148         """
# --> 149         rel_scores = self.label_relevance_score(topic_models, pmi_w2l)
#     150
#     151         if use_discrimination:
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in label_relevance_score(self, topic_models, pmi_w2l)
#      52
#      53
# ---> 54         assert topic_models.shape[1] == pmi_w2l.shape[0]
#      55         return np.asarray(np.asmatrix(topic_models) *
#      56                           np.asmatrix(pmi_w2l))
#
# AssertionError:
