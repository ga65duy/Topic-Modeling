# %%
import sys
sys.path.append('../..')
import src.Automatic_Topic_Labeling.lable_topic as tl
import src.Automatic_Topic_Labeling.helper_functions as hp
import src.data.data_loader as dl
from src.features.vectorizer import Vectorizer
from src.models.topic_models import TopicModel

# %%
language = "english"
type = "forum"
texttype = "thread_texts"
model = "lda"
pos = None

vec = Vectorizer.load('vectorizer/lda_english_forum_without_bigrams.pkl')
tm = TopicModel.load('topic_models/lda/ENFO_lda_english_forum_110.pkl')


docs = hp.load_doc(language, type, texttype,kind = "wobigrams")

labels = tl.get_topic_lables([],docs,pos,model,vec,tm,n_top_words = 15, n_cand_lables = 100,lable_min_df = 5, n_labels = 8)
# Out:
# shape topic model
# (110, 5798)
# pmishape
# (5798, 100)

# %%
print("\nTopical labels:")
print("-" * 20)
for i, labels in enumerate(labels):
    print(u"Topic {}: {}\n".format(
        i,
        ', '.join(map(lambda l: ' '.join(l), labels))
    ))
# Out:
# Topical labels:
# --------------------
# Topic 0: hocus pocus, ralph nader, kentucky bluegrass, prop37 citizens’, lorum ipsum, meatless mondays, tel number:+233, ig farben
#
# Topic 1: prop37 citizens’, engles chairman, impoverish repress, ralph nader, hocus pocus, user&apos;s privacy, homo sapiens, paris2015 cop21
#
# Topic 2: ralph nader, roman bobek, dina hamilton, kentucky bluegrass, mol creatinine, glutaric acidemia, ige mediate, healthyfood healthylifestyle
#
# Topic 3: ige mediate, kentucky bluegrass, meatless mondays, lorum ipsum, ricardo pascual, hocus pocus, markowicz toscano, marcela ortiz
#
# Topic 4: ralph nader, marcela ortiz, hocus pocus, engles chairman, lorum ipsum, tel number:+233, cytochrome p450, roman bobek
#
# Topic 5: dina hamilton, marcela ortiz, roman bobek, homo sapiens, engles chairman, ig farben, meatless mondays, ricardo pascual
#
# Topic 6: kentucky bluegrass, ralph nader, hocus pocus, cytochrome p450, user&apos;s privacy, paris2015 cop21, fischer tropsch, timothy bromwich
#
# Topic 7: chorus supernatural, badge honour, dismal betting, kids’ lemonade, healthyfood healthylifestyle, без глютена, healthylifestyle vegangood, vegangood dietdelight
#
# Topic 8: prop37 citizens’, engles chairman, impoverish repress, hocus pocus, barium strontium, mukul gupta, ralph nader, ig farben
#
# Topic 9: ig farben, homo sapiens, garcinia cambogia, chellie pingree, cytochrome p450, erectile dysfunction, engles chairman, paris2015 cop21
#
# Topic 10: fischer tropsch, ralph nader, user&apos;s privacy, ihs cera, roman bobek, hocus pocus, vegangood dietdelight, healthylifestyle vegangood
#
# Topic 11: timothy bromwich, marcela ortiz, roman bobek, jannie seaver, paris2015 cop21, lorum ipsum, ig farben, nikki lala
#
# Topic 12: fischer tropsch, tel number:+233, bodolay bowers, ralph nader, hocus pocus, meatless mondays, saxby chambliss, user&apos;s privacy
#
# Topic 13: lorum ipsum, hocus pocus, ralph nader, jannie seaver, badge honour, dismal betting, kids’ lemonade, timothy bromwich
#
# Topic 14: prop37 citizens’, tel number:+233, dina hamilton, lorum ipsum, saxby chambliss, engles chairman, ige mediate, roman bobek
#
# Topic 15: conjugated linoleic, ige mediate, без глютена, vegangood dietdelight, healthyfood healthylifestyle, пища healthyfood, органическая пища, глютена noallergiesfood
#
# Topic 16: hocus pocus, ralph nader, user&apos;s privacy, impoverish repress, ig farben, kentucky bluegrass, roman bobek, paris2015 cop21
#
# Topic 17: 🌷 🌷, emanuel farrow, bodolay bowers, conjugated linoleic, roman bobek, tel number:+233, marcela ortiz, meatless mondays
#
# Topic 18: timothy bromwich, ig farben, paris2015 cop21, homo sapiens, engles chairman, hocus pocus, impoverish repress, kentucky bluegrass
#
# Topic 19: hocus pocus, lutein zeaxanthin, badge honour, dismal betting, kids’ lemonade, healthylifestyle vegangood, без глютена, vegangood dietdelight
#
# Topic 20: fischer tropsch, ralph nader, hocus pocus, lorum ipsum, kentucky bluegrass, homo sapiens, user&apos;s privacy, engles chairman
#
# Topic 21: vegangood dietdelight, healthylifestyle vegangood, рекомендует organic#healthy, пища healthyfood, органическая пища, глютена noallergiesfood, гиппократ рекомендует, без глютена
#
# Topic 22: fischer tropsch, ralph nader, bodolay bowers, hocus pocus, jannie seaver, user&apos;s privacy, kentucky bluegrass, paris2015 cop21
#
# Topic 23: fischer tropsch, homo sapiens, ralph nader, user&apos;s privacy, hocus pocus, saxby chambliss, kentucky bluegrass, paris2015 cop21
#
# Topic 24: ihs cera, fischer tropsch, roman bobek, ralph nader, user&apos;s privacy, paris2015 cop21, kentucky bluegrass, jannie seaver
#
# Topic 25: bodolay bowers, jannie seaver, emanuel farrow, conjugated linoleic, kentucky bluegrass, roman bobek, marcela ortiz, meatless mondays
#
# Topic 26: marcela ortiz, hocus pocus, ralph nader, bodolay bowers, homo sapiens, roman bobek, kentucky bluegrass, mol creatinine
#
# Topic 27: engles chairman, ralph nader, emanuel farrow, kentucky bluegrass, impoverish repress, ig farben, saxby chambliss, homo sapiens
#
# Topic 28: user&apos;s privacy, ralph nader, healthylifestyle vegangood, пища healthyfood, органическая пища, глютена noallergiesfood, гиппократ рекомендует, без глютена
#
# Topic 29: novo nordisk, fischer tropsch, ralph nader, user&apos;s privacy, tel number:+233, homo sapiens, roman bobek, impoverish repress
#
# Topic 30: lutein zeaxanthin, elaine ingham, ige mediate, glutaric acidemia, mol creatinine, saxby chambliss, macular degeneration, jannie seaver
#
# Topic 31: tel number:+233, emanuel farrow, roman bobek, meatless mondays, bodolay bowers, impoverish repress, garcinia cambogia, waalkens breedlove
#
# Topic 32: hocus pocus, homo sapiens, ige mediate, ig farben, ralph nader, marcela ortiz, timothy bromwich, paris2015 cop21
#
# Topic 33: lorum ipsum, saxby chambliss, timothy bromwich, ig farben, paris2015 cop21, prop37 citizens’, kids’ lemonade, badge honour
#
# Topic 34: engles chairman, prop37 citizens’, ig farben, dina hamilton, impoverish repress, homo sapiens, timothy bromwich, meatless mondays
#
# Topic 35: vía orgánica, mol creatinine, glutaric acidemia, palestinian arabs, elaine ingham, conjugated linoleic, novo nordisk, lutein zeaxanthin
#
# Topic 36: mol creatinine, glutaric acidemia, lutein zeaxanthin, healthyfood healthylifestyle, healthylifestyle vegangood, рекомендует organic#healthy, пища healthyfood, органическая пища
#
# Topic 102: ihs cera, fischer tropsch, kentucky bluegrass, badge honour, kids’ lemonade, dismal betting, healthylifestyle vegangood, vegangood dietdelight
#
# Topic 103: roman bobek, prop37 citizens’, impoverish repress, chorus supernatural, homo sapiens, hocus pocus, user&apos;s privacy, kentucky bluegrass
#
# Topic 104: ralph nader, hocus pocus, homo sapiens, user&apos;s privacy, gish gallop, timothy bromwich, fischer tropsch, meatless mondays
#
# Topic 105: marcela ortiz, jannie seaver, roman bobek, dina hamilton, conjugated linoleic, emanuel farrow, gráinne o'carroll, bodolay bowers
#
# Topic 106: lorum ipsum, user&apos;s privacy, timothy bromwich, paris2015 cop21, ralph nader, healthylifestyle vegangood, healthyfood healthylifestyle, vegangood dietdelight
#
# Topic 107: dismal betting, kids’ lemonade, badge honour, рекомендует organic#healthy, пища healthyfood, органическая пища, глютена noallergiesfood, гиппократ рекомендует
#
# Topic 108: impoverish repress, hocus pocus, homo sapiens, ig farben, kentucky bluegrass, mukul gupta, ralph nader, nikki lala
#
# Topic 109: timothy bromwich, dismal betting, kids’ lemonade, badge honour, kenneth krause, без глютена, vegangood dietdelight, healthylifestyle vegangood

# %%
## ATL with bigrams

# %%
vec_bi = Vectorizer.load('vectorizer/ENFO_lda_english_forum.pkl')
tm_bi = TopicModel.load('topic_models/lda/ENED_lda_english_editorial_articles_130.pkl')

docs_bi = hp.load_doc(language, type, texttype,"with_2bigramms")

labels_bi = tl.get_topic_lables([],docs_bi,pos,model,vec_bi,tm_bi,n_top_words = 15, n_cand_lables = 100,lable_min_df = 5, n_labels = 8)


print("\nTopical labels:")
print("-" * 20)
for i, labels in enumerate(labels_bi):
        print(u"Topic {}: {}\n".format(
            i,
            ', '.join(map(lambda l: ' '.join(l), labels))
        ))
# Out:
# shape topic model
# (130, 6254)
# pmishape
# (5970, 100)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-35cb5ec325b7> in <module>()
#       4 docs_bi = hp.load_doc(language, type, texttype,"with_2bigramms")
#       5
# ----> 6 labels_bi = tl.get_topic_lables([],docs_bi,pos,model,vec_bi,tm_bi,n_top_words = 15, n_cand_lables = 100,lable_min_df = 5, n_labels = 8)
#       7
#       8
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\lable_topic.py in get_topic_lables(tagged_docs, docs, pos, model, vec, trained_tm, n_top_words, n_cand_lables, lable_min_df, n_labels)
#      51                                index2label=pmi_cal.index2label_,
#      52                                label_models=None,
# ---> 53                                k = n_labels)
#      54     return labels
#      55
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in top_k_labels(self, topic_models, pmi_w2l, index2label, label_models, k)
#     212         label_scores = self.combined_label_score(topic_models, pmi_w2l,
#     213                                                  self._discrimination,
# --> 214                                                  self._mu)
#     215
#     216         # print("lable scores")
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in combined_label_score(self, topic_models, pmi_w2l, use_discrimination, mu)
#     147             score for each topic and label pair
#     148         """
# --> 149         rel_scores = self.label_relevance_score(topic_models, pmi_w2l)
#     150
#     151         if use_discrimination:
#
# D:\Bachelorarbeit\Projekte\tm-maria\src\Automatic_Topic_Labeling\label_ranker.py in label_relevance_score(self, topic_models, pmi_w2l)
#      52
#      53
# ---> 54         assert topic_models.shape[1] == pmi_w2l.shape[0]
#      55         return np.asarray(np.asmatrix(topic_models) *
#      56                           np.asmatrix(pmi_w2l))
#
# AssertionError:
